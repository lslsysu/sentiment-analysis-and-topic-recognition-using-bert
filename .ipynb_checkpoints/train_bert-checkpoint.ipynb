# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
from transformers import AutoTokenizer, BertModel
import torch
import torch.nn as nn
import utils
import model

# %% [markdown]
# ## Construct Vocab

# %%
tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-chinese")

# %%
vocab_dict = tokenizer.get_vocab()
vocab = utils.Vocab()
vocab.construct_vocab(vocab_dict)

# %%
print(list(vocab.token_to_idx.items())[0:10])
# Out:
# [('[PAD]', 0), ('[unused1]', 1), ('[unused2]', 2), ('[unused3]', 3), ('[unused4]', 4), ('[unused5]', 5), ('[unused6]', 6), ('[unused7]', 7), ('[unused8]', 8), ('[unused9]', 9)]

# %% [markdown]
# ## Load Data

# %%
train_data = utils.load_data("./data/train.txt")
test_data = utils.load_data("./data/test.txt")

# %% [markdown]
# ## Construct Dataset

# %%
train_dataset = utils.llmstage0Dataset(train_data, max_len = 125, tokenizer = tokenizer, vocab = vocab)
test_dataset = utils.llmstage0Dataset(test_data, max_len = 125, tokenizer = tokenizer, vocab = vocab)
# Out:
# /home/lsl/LLM/Project/llm_stage0/utils.py:80: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.all_topic_labels = torch.tensor(data[1], dtype=torch.long)

# %%
torch.save(train_dataset, './result/train_dataset.pth')
torch.save(test_dataset, './result/test_dataset.pth')

# %%
batch_size = 256
train_iter = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle = True)
test_iter = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle = False)

# %%
# 查看DataLoader
for X, y, z in train_iter:
    print(X[0].shape)
    print(X[1].shape)
    print(y.shape)
    print(z.shape)
    break
# Out:
# torch.Size([256, 125])
# torch.Size([256, 125])
# torch.Size([256, 10])
# torch.Size([256])

# %% [markdown]
# ## Construct Model

# %%
num_topic_labels, num_sentiment_labels = 10, 3
net = model.MultiTaskBERT(num_topic_labels, num_sentiment_labels)

# %% [markdown]
# ## Train Bert

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net.to(device)
# trainer
optimizer = torch.optim.Adam(net.parameters(), lr=2e-5)
# loss
topic_loss_func = nn.BCEWithLogitsLoss()  
sentiment_loss_func = nn.CrossEntropyLoss()

# %%
num_epochs = 20
net, net_loss, topic_metrics, sentiment_metrics = utils.train_bert(net, num_epochs, train_iter, topic_loss_func, sentiment_loss_func, optimizer, device)
# Out:
# epoch 1/5
#   avg loss: 1.1503, topic loss: 0.4137, sentiment loss: 0.7366
#   sentiment accuracy: 0.7024, topic accuracy: 0.8653
# epoch 2/5
#   avg loss: 0.8995, topic loss: 0.3097, sentiment loss: 0.5898
#   sentiment accuracy: 0.7522, topic accuracy: 0.8816
# epoch 3/5
#   avg loss: 0.7917, topic loss: 0.2688, sentiment loss: 0.5228
#   sentiment accuracy: 0.7833, topic accuracy: 0.8996
# epoch 4/5
#   avg loss: 0.6896, topic loss: 0.2339, sentiment loss: 0.4557
#   sentiment accuracy: 0.8124, topic accuracy: 0.9153
# epoch 5/5
#   avg loss: 0.5820, topic loss: 0.2055, sentiment loss: 0.3765
#   sentiment accuracy: 0.8541, topic accuracy: 0.9241

# %%
torch.save(net.state_dict(), './result/bert_trained.pth')

# %%
# visualization
utils.visualize_epochs(net_loss[0], net_loss[1], net_loss[2], 
                 topic_metrics[0], topic_metrics[1], topic_metrics[2], topic_metrics[3],
                 sentiment_metrics[0], sentiment_metrics[1], sentiment_metrics[2], sentiment_metrics[3])

# %% [markdown]
# ## Test Bert

# %%
utils.test_bert(net, test_iter, device)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2903288/606953076.py", line 1, in <module>
#     utils.test_bert(net, test_iter, device)
#   File "/home/lsl/LLM/Project/llm_stage0/utils.py", line 419, in test_bert
# NameError: name 'test_topic_metrics' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/lsl/miniconda3/envs/llm_stage0_env/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
